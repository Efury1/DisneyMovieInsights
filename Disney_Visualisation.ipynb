# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler



# Load the dataset
file_path = 'output/disney_movies.csv'  
try:
    df = pd.read_csv(file_path)
    print("Dataset loaded successfully!")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
print("=" * 40)


#Check shape 
print("Shape:", df.shape)
print("=" * 40)

# Check if dataset is unquie 
movieUnquie = df['movie_title'].is_unique
print("Is movie id unquie:", movieUnquie)

# Since movie data isn't unquie, we want to use a combination of columns ot create a unquie identifier
df['unique_id'] = df['movie_title'] + "_" + df['release_date'].astype(str)

#Unsure what I want to do with missing data in genre and mpaa_rating, as I'm not sure if I want ot just drop

# Since this isn't unquie
print("=" * 40)

# Display types
# info
df.info()
print("=" * 40)

# Remove null titles
df = df.dropna(subset=['movie_title'])


#Check shape 
print("Shape:", df.shape)
print("=" * 40)

# Exact year and make own column
df['release_year'] = pd.to_datetime(df['release_date']).dt.year

# Display the first few rows of the dataset
df.head(20)


#Clean missing or inconsistent values.

#Convert dates into usable formats (e.g., extract year from release_date).
#Handle categorical data (e.g., genre and mpaa_rating) using encoding techniques.
#Normalize numerical data like total_gross and inflation_adjusted_gross.

#Pre-processing
#Encode categorical variables using techniques like one-hot encoding or label encoding.
#Scale numerical variables (total_gross, inflation_adjusted_gross) using standardization (z-score normalization) or min-max normalization.

# EDA

#Visualize gross revenue trends over time.
#Analyze genre distribution and its relationship with mpaa_rating and revenue.
#Compare total_gross with inflation_adjusted_gross.
#Identify the most and least successful movies.
#Check for outliers and anomalies.

# Clustering Disney Movies
#Cluster movies based on features like total_gross, inflation_adjusted_gross, and release_date.
#Use algorithms like k-means and hierarchical clustering to group similar movies.
#Visualize clusters using dimensionality reduction (e.g., PCA).

# Predicting Financial Success (Supervised Learning)
#Define success metrics (e.g., gross revenue above a threshold is "successful").
#Build a classification model (e.g., decision tree, logistic regression) to predict movie success.
#Build a regression model (e.g., linear regression, random forest) to predict total_gross
#Split the data into training and testing sets.
#Train models and evaluate performance using metrics like accuracy, precision, recall (for classification) or RMSE (for regression).
#Perform hyperparameter tuning using GridSearchCV or RandomSearchCV

# Evaluati9on and Insights4 
#Compare the performance of different models.
#Identify key factors contributing to a movie's success (e.g., genre, year, rating).
#Summarize actionable insights for Disney's movie-making strategies.

#Explore ensemble methods like Random Forest, Gradient Boosting, or XGBoost
#Perform sentiment analysis on movie reviews (if additional text data is available).
# Out:
# Dataset loaded successfully!
# ...
# Shape: (579, 6)
# ...
# Is movie id unquie: False
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
#  6   unique_id                 579 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 31.8+ KB
# ...
# Shape: (579, 7)
# ...
#                         movie_title release_date      genre mpaa_rating  \
# 0   Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                         Pinocchio   1940-02-09  Adventure           G
# ...

# %%
#
